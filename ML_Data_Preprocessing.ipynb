# %% [markdown]
# <a href="https://colab.research.google.com/github/Simeen01/Machine-Learning/blob/main/ML_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/Datasets/Movierating_encoding.csv"

# %% [markdown]
# Categrical variable encoding:
# - only ordinals can be converted
# - ordinal to numerical

# %%
df = pd.read_csv(path)
df
# Out:
#    TOTAL_BILL     SEX  DAY    TIME  SIZE
# 0         250  female  sun  Dinner     5
# 1         260  female  sat  Dinner     6
# 2         350  female  sat  Dinner     4
# 3         250    male  sun   Lunch     3
# 4         892    male  sat   Lunch     0
# 5         745  female  sun  Dinner     2
# 6         455    male  fri  Dinner     4
# 7         564    male  fri  Dinner     0
# 8         452  female  sat   Lunch     2
# 9         456    male  sun   Lunch     1

# %%
df.shape
# Out:
# (10, 5)

# %%
#get_dummies : categorical to numerical
df1 = pd.get_dummies(df) #feature engineering
df1
# Out:
#    TOTAL_BILL  SIZE  SEX_female  SEX_male  DAY_fri  DAY_sat  DAY_sun  \
# 0         250     5           1         0        0        0        1
# 1         260     6           1         0        0        1        0
# 2         350     4           1         0        0        1        0
# 3         250     3           0         1        0        0        1
# 4         892     0           0         1        0        1        0
# 5         745     2           1         0        0        0        1
# 6         455     4           0         1        1        0        0
# 7         564     0           0         1        1        0        0
# 8         452     2           1         0        0        1        0
# 9         456     1           0         1        0        0        1
#
#    TIME_Dinner  TIME_Lunch
# 0            1           0
# 1            1           0
# 2            1           0
# 3            0           1
# 4            0           1
# 5            1           0
# ...

# %%
df1.shape
# Out:
# (10, 9)

# %%
#drop first column of each feature (sex,day,time)
df1 = pd.get_dummies(df,drop_first=True)
df1
# Out:
#    TOTAL_BILL  SIZE  SEX_male  DAY_sat  DAY_sun  TIME_Lunch
# 0         250     5         0        0        1           0
# 1         260     6         0        1        0           0
# 2         350     4         0        1        0           0
# 3         250     3         1        0        1           1
# 4         892     0         1        1        0           1
# 5         745     2         0        0        1           0
# 6         455     4         1        0        0           0
# 7         564     0         1        0        0           0
# 8         452     2         0        1        0           1
# 9         456     1         1        0        1           1
